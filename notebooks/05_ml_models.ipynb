# %% [markdown]
# # 05 Classical ML Models

# %%
import sys
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.config import FEATURES_DIR, MODELS_DIR
from src.features.build_features import build_feature_table
from src.models.ml_models import train_grouped_model, save_model

# %%
features_path = FEATURES_DIR / 'trial_features.csv'
features = pd.read_csv(features_path) if features_path.exists() else build_feature_table(ROOT / 'archive')
features.head()

# %%
hr_model, hr_metrics = train_grouped_model(features, target='hr_mean', task='regression')
save_model(hr_model, MODELS_DIR / 'hr_regressor.joblib')
hr_metrics

# %%
load_model, load_metrics = train_grouped_model(features, target='cv_load_class', task='classification')
save_model(load_model, MODELS_DIR / 'cv_load_classifier.joblib')
load_metrics

# %%
bp_model, bp_metrics = train_grouped_model(features, target='bp_proxy_score', task='regression')
save_model(bp_model, MODELS_DIR / 'bp_proxy_regressor.joblib')
bp_metrics
