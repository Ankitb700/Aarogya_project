# %% [markdown]
# # 01 Archive Inspection

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.config import ARCHIVE_DIR
from src.data.archive_scanner import scan_archive, trial_manifest
from src.utils.validation import validate_archive

# %%
summary = validate_archive(ARCHIVE_DIR)
summary

# %%
records = scan_archive(ARCHIVE_DIR)
manifest = trial_manifest(ARCHIVE_DIR)
manifest[['subject_id', 'trial_id', 'empatica_path', 'video_path', 'has_bvp', 'has_hr', 'has_ibi', 'has_tags']]
