# %% [markdown]
# # 04 Feature Engineering

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.config import ARCHIVE_DIR, FEATURES_DIR
from src.features.build_features import build_feature_table, save_feature_table
from src.utils.validation import assert_feature_table_ok

# %%
features = build_feature_table(ARCHIVE_DIR)
assert_feature_table_ok(features)
features

# %%
path = save_feature_table(ARCHIVE_DIR, FEATURES_DIR / 'trial_features.csv')
path
