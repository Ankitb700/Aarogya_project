# %% [markdown]
# # 02 Data Alignment

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.config import ARCHIVE_DIR, ALIGNED_DIR, ML_RESAMPLE_HZ
from src.data.archive_scanner import scan_archive
from src.data.alignment import align_trial, save_aligned_trial
from src.utils.plotting import plot_aligned_signals

# %%
records = scan_archive(ARCHIVE_DIR)
record = records[0]
aligned, meta = align_trial(record, hz=ML_RESAMPLE_HZ)
meta, aligned.head()

# %%
plot_aligned_signals(aligned)

# %%
saved = [save_aligned_trial(record, ALIGNED_DIR, hz=ML_RESAMPLE_HZ) for record in records]
saved[:3], len(saved)
