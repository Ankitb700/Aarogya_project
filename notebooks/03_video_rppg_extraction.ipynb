# %% [markdown]
# # 03 Video rPPG Extraction

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.config import ARCHIVE_DIR, FEATURES_DIR
from src.data.archive_scanner import scan_archive
from src.video.rppg import extract_video_rgb_traces

# %%
records = scan_archive(ARCHIVE_DIR)
record = next(r for r in records if r.video_path is not None)
record.video_path

# %%
# Increase max_frames after inspecting speed and ROI quality.
traces = extract_video_rgb_traces(record.video_path, max_frames=300)
traces.head()

# %%
traces[['rppg_green', 'rppg_chrom', 'rppg_pos', 'brightness']].plot(figsize=(14, 5), subplots=True)
